# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
winedata=pd.read_csv("/winequality-red.csv")

# %%
wd=winedata

# %%
wd
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 0         9.4        5
# 1         9.8        5
# 2         9.8        5
# 3         9.8        6
# 4         9.4        5
# ...       ...      ...
# 1594     10.5        5
# 1595     11.2        6
# 1596     11.0        6
# 1597     10.2        5
# 1598     11.0        6
#
# [1599 rows x 12 columns]

# %%
wd.isna().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
cor=wd.corr()
plt.subplots(figsize=(10,6))
sns.heatmap(cor,annot=True,vmin=-0.5,vmax=0.99)
# Out:
# <Axes: >

# %%
wd.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
wd['quality'].unique()
# Out:
# array([5, 6, 7, 4, 8, 3])

# %%
wd.describe().T.style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_2023d_row0_col0, #T_2023d_row1_col0, #T_2023d_row1_col7, #T_2023d_row2_col0, #T_2023d_row2_col3, #T_2023d_row2_col4, #T_2023d_row2_col7, #T_2023d_row3_col0, #T_2023d_row4_col0, #T_2023d_row4_col1, #T_2023d_row4_col2, #T_2023d_row4_col3, #T_2023d_row4_col4, #T_2023d_row4_col5, #T_2023d_row4_col6, #T_2023d_row4_col7, #T_2023d_row5_col0, #T_2023d_row6_col0, #T_2023d_row7_col0, #T_2023d_row7_col2, #T_2023d_row7_col7, #T_2023d_row8_col0, #T_2023d_row9_col0, #T_2023d_row10_col0, #T_2023d_row11_col0 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_2023d_row0_col1, #T_2023d_row10_col6 {
#   background-color: #d4e4f4;
#   color: #000000;
# }
# #T_2023d_row0_col2, #T_2023d_row0_col7, #T_2023d_row3_col1, #T_2023d_row3_col7, #T_2023d_row8_col6 {
#   background-color: #edf4fc;
#   color: #000000;
# }
# #T_2023d_row0_col3 {
#   background-color: #5ba3d0;
#   color: #f1f1f1;
# }
# #T_2023d_row0_col4 {
#   background-color: #afd1e7;
#   color: #000000;
# }
# #T_2023d_row0_col5 {
#   background-color: #cfe1f2;
#   color: #000000;
# }
# #T_2023d_row0_col6 {
#   background-color: #dae8f6;
#   color: #000000;
# }
# #T_2023d_row1_col1, #T_2023d_row1_col5, #T_2023d_row1_col6, #T_2023d_row9_col6 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_2023d_row1_col2, #T_2023d_row2_col1, #T_2023d_row2_col2, #T_2023d_row2_col5, #T_2023d_row2_col6, #T_2023d_row8_col2, #T_2023d_row9_col2, #T_2023d_row9_col7 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_2023d_row1_col3, #T_2023d_row1_col4, #T_2023d_row7_col6, #T_2023d_row8_col7, #T_2023d_row9_col1, #T_2023d_row9_col5 {
#   background-color: #f5f9fe;
#   color: #000000;
# }
# #T_2023d_row3_col2, #T_2023d_row3_col6, #T_2023d_row7_col4, #T_2023d_row9_col3 {
#   background-color: #eff6fc;
#   color: #000000;
# }
# #T_2023d_row3_col3 {
#   background-color: #e2edf8;
#   color: #000000;
# }
# #T_2023d_row3_col4, #T_2023d_row8_col5 {
#   background-color: #e7f0fa;
#   color: #000000;
# }
# #T_2023d_row3_col5 {
#   background-color: #ecf4fb;
#   color: #000000;
# }
# #T_2023d_row5_col1 {
#   background-color: #a9cfe5;
#   color: #000000;
# }
# #T_2023d_row5_col2 {
#   background-color: #b0d2e7;
#   color: #000000;
# }
# #T_2023d_row5_col3, #T_2023d_row7_col3, #T_2023d_row11_col1 {
#   background-color: #dfecf7;
#   color: #000000;
# }
# #T_2023d_row5_col4 {
#   background-color: #b2d2e8;
#   color: #000000;
# }
# #T_2023d_row5_col5 {
#   background-color: #a1cbe2;
#   color: #000000;
# }
# #T_2023d_row5_col6 {
#   background-color: #aacfe5;
#   color: #000000;
# }
# #T_2023d_row5_col7 {
#   background-color: #c7dbef;
#   color: #000000;
# }
# #T_2023d_row6_col1, #T_2023d_row6_col2, #T_2023d_row6_col4, #T_2023d_row6_col5, #T_2023d_row6_col6, #T_2023d_row6_col7, #T_2023d_row10_col3 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_2023d_row6_col3 {
#   background-color: #2b7bba;
#   color: #f1f1f1;
# }
# #T_2023d_row7_col1, #T_2023d_row9_col4 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_2023d_row7_col5, #T_2023d_row11_col2, #T_2023d_row11_col7 {
#   background-color: #f2f8fd;
#   color: #000000;
# }
# #T_2023d_row8_col1 {
#   background-color: #eaf2fb;
#   color: #000000;
# }
# #T_2023d_row8_col3 {
#   background-color: #aed1e7;
#   color: #000000;
# }
# #T_2023d_row8_col4 {
#   background-color: #dbe9f6;
#   color: #000000;
# }
# #T_2023d_row10_col1, #T_2023d_row11_col4 {
#   background-color: #cbdef1;
#   color: #000000;
# }
# #T_2023d_row10_col2 {
#   background-color: #f1f7fd;
#   color: #000000;
# }
# #T_2023d_row10_col4 {
#   background-color: #87bddc;
#   color: #000000;
# }
# #T_2023d_row10_col5 {
#   background-color: #c1d9ed;
#   color: #000000;
# }
# #T_2023d_row10_col7 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_2023d_row11_col3 {
#   background-color: #a4cce3;
#   color: #000000;
# }
# #T_2023d_row11_col5 {
#   background-color: #d9e7f5;
#   color: #000000;
# }
# #T_2023d_row11_col6 {
#   background-color: #e4eff9;
#   color: #000000;
# }
# </style>
# <table id="T_2023d" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2023d_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_2023d_level0_col1" class="col_heading level0 col1" >mean</th>
#       <th id="T_2023d_level0_col2" class="col_heading level0 col2" >std</th>
#       <th id="T_2023d_level0_col3" class="col_heading level0 col3" >min</th>
#       <th id="T_2023d_level0_col4" class="col_heading level0 col4" >25%</th>
#       <th id="T_2023d_level0_col5" class="col_heading level0 col5" >50%</th>
#       <th id="T_2023d_level0_col6" class="col_heading level0 col6" >75%</th>
#       <th id="T_2023d_level0_col7" class="col_heading level0 col7" >max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2023d_level0_row0" class="row_heading level0 row0" >fixed acidity</th>
#       <td id="T_2023d_row0_col0" class="data row0 col0" >1599.000000</td>
#       <td id="T_2023d_row0_col1" class="data row0 col1" >8.319637</td>
#       <td id="T_2023d_row0_col2" class="data row0 col2" >1.741096</td>
#       <td id="T_2023d_row0_col3" class="data row0 col3" >4.600000</td>
#       <td id="T_2023d_row0_col4" class="data row0 col4" >7.100000</td>
#       <td id="T_2023d_row0_col5" class="data row0 col5" >7.900000</td>
#       <td id="T_2023d_row0_col6" class="data row0 col6" >9.200000</td>
#       <td id="T_2023d_row0_col7" class="data row0 col7" >15.900000</td>
#     </tr>
#     <tr>
#       <th id="T_2023d_level0_row1" class="row_heading level0 row1" >volatile acidity</th>
#       <td id="T_2023d_row1_col0" class="data row1 col0" >1599.000000</td>
#       <td id="T_2023d_row1_col1" class="data row1 col1" >0.527821</td>
#       <td id="T_2023d_row1_col2" class="data row1 col2" >0.179060</td>
#       <td id="T_2023d_row1_col3" class="data row1 col3" >0.120000</td>
#       <td id="T_2023d_row1_col4" class="data row1 col4" >0.390000</td>
#       <td id="T_2023d_row1_col5" class="data row1 col5" >0.520000</td>
#       <td id="T_2023d_row1_col6" class="data row1 col6" >0.640000</td>
#       <td id="T_2023d_row1_col7" class="data row1 col7" >1.580000</td>
#     </tr>
#     <tr>
#       <th id="T_2023d_level0_row2" class="row_heading level0 row2" >citric acid</th>
#       <td id="T_2023d_row2_col0" class="data row2 col0" >1599.000000</td>
#       <td id="T_2023d_row2_col1" class="data row2 col1" >0.270976</td>
#       <td id="T_2023d_row2_col2" class="data row2 col2" >0.194801</td>
#       <td id="T_2023d_row2_col3" class="data row2 col3" >0.000000</td>
#       <td id="T_2023d_row2_col4" class="data row2 col4" >0.090000</td>
#       <td id="T_2023d_row2_col5" class="data row2 col5" >0.260000</td>
#       <td id="T_2023d_row2_col6" class="data row2 col6" >0.420000</td>
#       <td id="T_2023d_row2_col7" class="data row2 col7" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_2023d_level0_row3" class="row_heading level0 row3" >residual sugar</th>
#       <td id="T_2023d_row3_col0" class="data row3 col0" >1599.000000</td>
#       <td id="T_2023d_row3_col1" class="data row3 col1" >2.538806</td>
#       <td id="T_2023d_row3_col2" class="data row3 col2" >1.409928</td>
#       <td id="T_2023d_row3_col3" class="data row3 col3" >0.900000</td>
#       <td id="T_2023d_row3_col4" class="data row3 col4" >1.900000</td>
#       <td id="T_2023d_row3_col5" class="data row3 col5" >2.200000</td>
#       <td id="T_2023d_row3_col6" class="data row3 col6" >2.600000</td>
#       <td id="T_2023d_row3_col7" class="data row3 col7" >15.500000</td>
#     </tr>
#     <tr>
#       <th id="T_2023d_level0_row4" class="row_heading level0 row4" >chlorides</th>
#       <td id="T_2023d_row4_col0" class="data row4 col0" >1599.000000</td>
#       <td id="T_2023d_row4_col1" class="data row4 col1" >0.087467</td>
#       <td id="T_2023d_row4_col2" class="data row4 col2" >0.047065</td>
#       <td id="T_2023d_row4_col3" class="data row4 col3" >0.012000</td>
#       <td id="T_2023d_row4_col4" class="data row4 col4" >0.070000</td>
#       <td id="T_2023d_row4_col5" class="data row4 col5" >0.079000</td>
#       <td id="T_2023d_row4_col6" class="data row4 col6" >0.090000</td>
#       <td id="T_2023d_row4_col7" class="data row4 col7" >0.611000</td>
#     </tr>
#     <tr>
#       <th id="T_2023d_level0_row5" class="row_heading level0 row5" >free sulfur dioxi

# %%
wd.quality.value_counts()
# Out:
# quality
# 5    681
# 6    638
# 7    199
# 4     53
# 8     18
# 3     10
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

wd.hist(bins = 50, figsize = (20,15))
plt.show()

# %%
plt.figure(figsize=(12,7))
sns.boxplot(x='quality',y='alcohol',data=wd)
plt.show()

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2)

# %%
x = wd.drop(["quality"],axis=1)
y = wd["quality"]

# %%
x.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol
# 0      9.4
# 1      9.8
# 2      9.8
# 3      9.8
# 4      9.4

# %%
y
# Out:
# 0       5
# 1       5
# 2       5
# 3       6
# 4       5
#        ..
# 1594    5
# 1595    6
# 1596    6
# 1597    5
# 1598    6
# Name: quality, Length: 1599, dtype: int64

# %%
from sklearn.linear_model import LogisticRegression
reg = LogisticRegression()
reg.fit(x_train,y_train)
regpred = reg.predict(x_test)

from sklearn.metrics import classification_report,confusion_matrix,accuracy_score
print(classification_report(y_test,regpred))
print("Accuracy of Logistic Regression is : ",accuracy_score(y_test,regpred)*100)
# Out:
#               precision    recall  f1-score   support
#
#            3       0.00      0.00      0.00         1
#            4       0.00      0.00      0.00        15
#            5       0.65      0.74      0.69       133
#            6       0.49      0.65      0.56       124
#            7       0.50      0.03      0.05        40
#            8       0.00      0.00      0.00         7
#
#     accuracy                           0.56       320
#    macro avg       0.27      0.24      0.22       320
# weighted avg       0.52      0.56      0.51       320
#
# Accuracy of Logistic Regression is :  56.25
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

print("Mean Absolute Error : ",mean_absolute_error(y_test,regpred))
print("Mean Squared Error : ",mean_squared_error(y_test,regpred))
print("Root Mean Squared Error : ",np.sqrt(mean_squared_error(y_test,regpred)))
print("R2 Score : ",r2_score(y_test,regpred))
# Out:
# Mean Absolute Error :  0.484375
# Mean Squared Error :  0.578125
# Root Mean Squared Error :  0.7603453162872774
# R2 Score :  0.19844020797227035

# %%
plt.figure(figsize=(6,4))
sns.heatmap(confusion_matrix(y_test,regpred),annot=True,cmap="RdPu")
plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.title("Confusion Matrix")
plt.show()
